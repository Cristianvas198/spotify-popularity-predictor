# %% [markdown]
# # API SPOTIFY

# %% [markdown]
# ## Librerias

# %%
import os
import warnings
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
from tqdm import tqdm
import time
from dotenv import dotenv_values

# Se filtran las advertencias.
warnings.filterwarnings('ignore')

# %%
config = dotenv_values(".env")

# Se obtienen credenciales desde variables de entorno
client_id = config["SPOTIFY_CLIENT_ID"]
client_secret = config['SPOTIFY_CLIENT_SECRET']

# Se crea el cliente que se utilizará para consumir la API.
client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 4
#       1 config = dotenv_values(".env")
#       3 # Se obtienen credenciales desde variables de entorno
# ----> 4 client_id = config["SPOTIFY_CLIENT_ID"]
#       5 client_secret = config['SPOTIFY_CLIENT_SECRET']
#       7 # Se crea el cliente que se utilizará para consumir la API.
#
# KeyError: 'SPOTIFY_CLIENT_ID'

# %%
generos = [
    'acoustic', 'afrobeat', 'alt-rock', 'alternative', 'ambient',
       'anime', 'black-metal', 'bluegrass', 'blues', 'brazil',
       'breakbeat', 'british', 'cantopop', 'chicago-house', 'children',
       'chill', 'classical', 'club', 'comedy', 'country', 'dance',
       'dancehall', 'death-metal', 'deep-house', 'detroit-techno',
       'disco', 'disney', 'drum-and-bass', 'dub', 'dubstep', 'edm',
       'electro', 'electronic', 'emo', 'folk', 'forro', 'french', 'funk',
       'garage', 'german', 'gospel', 'goth', 'grindcore', 'groove',
       'grunge', 'guitar', 'happy', 'hard-rock', 'hardcore', 'hardstyle',
       'heavy-metal', 'hip-hop', 'honky-tonk', 'house', 'idm', 'indian',
       'indie-pop', 'indie', 'industrial', 'iranian', 'j-dance', 'j-idol',
       'j-pop', 'j-rock', 'jazz', 'k-pop', 'kids', 'latin', 'latino',
       'malay', 'mandopop', 'metal', 'metalcore', 'minimal-techno', 'mpb',
       'new-age', 'opera', 'pagode', 'party', 'piano', 'pop-film', 'pop',
       'power-pop', 'progressive-house', 'psych-rock', 'punk-rock',
       'punk', 'r-n-b', 'reggae', 'reggaeton', 'rock-n-roll', 'rock',
       'rockabilly', 'romance', 'sad', 'salsa', 'samba', 'sertanejo',
       'show-tunes', 'singer-songwriter', 'ska', 'sleep', 'songwriter',
       'soul', 'spanish', 'study', 'swedish', 'synth-pop', 'tango',
       'techno', 'trance', 'trip-hop', 'turkish', 'world-music'
]

tracks_data = []

# %%
# Iterar sobre los géneros y recopilar datos
for genero in tqdm(generos, desc="Obteniendo canciones por género"):
    results = sp.search(q=f"genre:{genero}", type="track", limit=10)
    tracks_data.extend(results['tracks']['items'])
    time.sleep(1)  # Espera para evitar bloqueos por exceso de solicitudes

# Convertir los datos en un DataFrame
df = pd.DataFrame(tracks_data)

print(f"Total de canciones obtenidas: {len(df)}")
# Out:
# Obteniendo canciones por género: 100%|██████████| 114/114 [02:15<00:00,  1.19s/it]
# Total de canciones obtenidas: 1130

# %%
df
# Out:
#                                                  album  \
# 0    {'album_type': 'album', 'artists': [{'external...
# 1    {'album_type': 'album', 'artists': [{'external...
# 2    {'album_type': 'single', 'artists': [{'externa...
# 3    {'album_type': 'album', 'artists': [{'external...
# 4    {'album_type': 'single', 'artists': [{'externa...
# ..                                                 ...
# 595  {'album_type': 'album', 'artists': [{'external...
# 596  {'album_type': 'album', 'artists': [{'external...
# 597  {'album_type': 'album', 'artists': [{'external...
# 598  {'album_type': 'album', 'artists': [{'external...
# 599  {'album_type': 'compilation', 'artists': [{'ex...
#
#                                                artists  \
# 0    [{'external_urls': {'spotify': 'https://open.s...
# 1    [{'external_urls': {'spotify': 'https://open.s...
# 2    [{'external_urls': {'spotify': 'https://open.s...
# 3    [{'external_urls': {'spotify': 'https://open.s...
# ...
